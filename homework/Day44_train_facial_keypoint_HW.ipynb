# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'D:\\data\\training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\IVAN\AppData\Roaming\Python\Python35\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0097 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00252, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 0.0025 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00252 to 0.00202, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00202 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 0.0014 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 277us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00184
# Epoch 6/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00180, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 9.8414e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss did not improve from 0.00180
# Epoch 8/150
# 1712/1712 [==============================] - 0s 281us/step - loss: 8.8796e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00180 to 0.00165, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 279us/step - loss: 7.6227e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00165 to 0.00153, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 6.8956e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00153 to 0.00139, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 280us/step - loss: 6.0725e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00139 to 0.00127, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 5.5165e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00127 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 5.2309e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00111, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 4.7569e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00111 to 0.00108, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 4.4477e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00108 to 0.00104, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 4.2317e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00104 to 0.00100, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 3.9952e-04 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00100
# Epoch 18/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 3.8963e-04 - val_loss: 9.5075e-04
#
# Epoch 00018: val_loss improved from 0.00100 to 0.00095, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 3.6272e-04 - val_loss: 9.0836e-04
#
# Epoch 00019: val_loss improved from 0.00095 to 0.00091, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 3.5201e-04 - val_loss: 8.8946e-04
#
# Epoch 00020: val_loss improved from 0.00091 to 0.00089, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 3.4052e-04 - val_loss: 8.9706e-04
#
# Epoch 00021: val_loss did not improve from 0.00089
# Epoch 22/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 3.2485e-04 - val_loss: 8.9890e-04
#
# Epoch 00022: val_loss did not improve from 0.00089
# Epoch 23/150
# 1712/1712 [==============================] - 0s 275us/step - loss: 3.1703e-04 - val_loss: 8.9031e-04
#
# Epoch 00023: val_loss did not improve from 0.00089
# Epoch 24/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 3.0744e-04 - val_loss: 8.5642e-04
#
# Epoch 00024: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 2.9283e-04 - val_loss: 8.7519e-04
#
# Epoch 00025: val_loss did not improve from 0.00086
# Epoch 26/150
# 1712/1712 [==============================] - 0s 275us/step - loss: 2.8429e-04 - val_loss: 8.9891e-04
#
# Epoch 00026: val_loss did not improve from 0.00086
# Epoch 27/150
# 1712/1712 [==============================] - 0s 276us/step - loss: 2.8655e-04 - val_loss: 8.5801e-04
#
# Epoch 00027: val_loss did not improve from 0.00086
# Epoch 28/150
# 1712/1712 [==============================] - 0s 274us/step - loss: 2.7364e-04 - val_loss: 8.2579e-04
#
# Epoch 00028: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 2.7114e-04 - val_loss: 8.3287e-04
#
# Epoch 00029: val_loss did not improve from 0.00083
# Epoch 30/150
# 1712/1712 [==============================] - 0s 275us/step - loss: 2.6012e-04 - val_loss: 8.7603e-04
#
# Epoch 00030: val_loss did not improve from 0.00083
# Epoch 31/150
# 1712/1712 [==============================] - 0s 282us/step - loss: 2.6470e-04 - val_loss: 8.5658e-04
#
# Epoch 00031: val_loss did not improve from 0.00083
# Epoch 32/150
# 1712/1712 [==============================] - 0s 277us/step - loss: 2.5038e-04 - val_loss: 8.4284e-04
#
# Epoch 00032: val_loss did not improve from 0.00083
# Epoch 33/150
# 1712/1712 [==============================] - 0s 285us/step - loss: 2.5084e-04 - val_loss: 8.4715e-04
#
# Epoch 00033: val_loss did not improve from 0.00083
# Epoch 34/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 2.4705e-04 - val_loss: 8.8893e-04
#
# Epoch 00034: val_loss did not improve from 0.00083
# Epoch 35/150
# 1712/1712 [==============================] - 0s 284us/step - loss: 2.3699e-04 - val_loss: 8.1331e-04
#
# Epoch 00035: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 276us/step - loss: 2.3434e-04 - val_loss: 8.3039e-04
#
# Epoch 00036: val_loss did not improve from 0.00081
# Epoch 37/150
# 1712/1712 [==============================] - 0s 283us/step - loss: 2.3025e-04 - val_loss: 8.3464e-04
#
# Epoch 00037: val_loss did not improve from 0.00081
# Epoch 38/150
# 1712/1712 [==============================] - 0s 275us/step - loss: 2.2449e-04 - val_loss: 8.1270e-04
#
# Epoch 00038: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 2.2345e-04 - val_loss: 8.1236e-04
#
# Epoch 00039: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 2.1468e-04 - val_loss: 8.1171e-04
#
# Epoch 00040: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 0s 283us/step - loss: 2.1071e-04 - val_loss: 8.2491e-04
#
# Epoch 00041: val_loss did not improve from 0.00081
# Epoch 42/150
# 1712/1712 [==============================] - 0s 280us/step - loss: 2.1676e-04 - val_loss: 7.8362e-04
#
# Epoch 00042: val_loss improved from 0.00081 to 0.00078, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 0s 285us/step - loss: 2.0982e-04 - val_loss: 8.0761e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 0s 281us/step - loss: 2.0298e-04 - val_loss: 8.2147e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 0s 277us/step - loss: 1.9877e-04 - val_loss: 8.0084e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 2.0206e-04 - val_loss: 8.4717e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 0s 288us/step - loss: 1.9793e-04 - val_loss: 8.0147e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 1.8876e-04 - val_loss: 8.4245e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.9255e-04 - val_loss: 8.0907e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 1.9824e-04 - val_loss: 8.4173e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 0s 278us/step - loss: 1.8674e-04 - val_loss: 8.2426e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 0s 275us/step - loss: 1.8532e-04 - val_loss: 8.0356e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.8234e-04 - val_loss: 8.0287e-04
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.7864e-04 - val_loss: 8.4779e-04
#
# Epoch 00054: val_loss did not improve from 0.00078
# Epoch 55/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.8397e-04 - val_loss: 8.5082e-04
#
# Epoch 00055: val_loss did not improve from 0.00078
# Epoch 56/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.8050e-04 - val_loss: 8.2306e-04
#
# Epoch 00056: val_loss did not improve from 0.00078
# Epoch 57/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.7343e-04 - val_loss: 8.0897e-04
#
# Epoch 00057: val_loss did not improve from 0.00078
# Epoch 58/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.7124e-04 - val_loss: 8.4672e-04
#
# Epoch 00058: val_loss did not improve from 0.00078
# Epoch 59/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.7281e-04 - val_loss: 8.2056e-04
#
# Epoch 00059: val_loss did not improve from 0.00078
# Epoch 60/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.6881e-04 - val_loss: 7.8952e-04
#
# Epoch 00060: val_loss did not improve from 0.00078
# Epoch 61/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.6639e-04 - val_loss: 8.0696e-04
#
# Epoch 00061: val_loss did not improve from 0.00078
# Epoch 62/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.6755e-04 - val_loss: 7.9419e-04
#
# Epoch 00062: val_loss did not improve from 0.00078
# Epoch 63/150
# 1712/1712 [==============================] - 0s 267us/step - loss: 1.6136e-04 - val_loss: 7.8006e-04
#
# Epoch 00063: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.6482e-04 - val_loss: 8.4210e-04
#
# Epoch 00064: val_loss did not improve from 0.00078
# Epoch 65/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.6066e-04 - val_loss: 8.3557e-04
#
# Epoch 00065: val_loss did not improve from 0.00078
# Epoch 66/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.5827e-04 - val_loss: 7.9461e-04
#
# Epoch 00066: val_loss did not improve from 0.00078
# Epoch 67/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.5587e-04 - val_loss: 8.0693e-04
#
# Epoch 00067: val_loss did not improve from 0.00078
# Epoch 68/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.5663e-04 - val_loss: 8.1337e-04
#
# Epoch 00068: val_loss did not improve from 0.00078
# Epoch 69/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.5310e-04 - val_loss: 8.1237e-04
#
# Epoch 00069: val_loss did not improve from 0.00078
# Epoch 70/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.5297e-04 - val_loss: 8.1153e-04
#
# Epoch 00070: val_loss did not improve from 0.00078
# Epoch 71/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.5213e-04 - val_loss: 8.0513e-04
#
# Epoch 00071: val_loss did not improve from 0.00078
# Epoch 72/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.5054e-04 - val_loss: 8.5260e-04
#
# Epoch 00072: val_loss did not improve from 0.00078
# Epoch 73/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.5200e-04 - val_loss: 8.0755e-04
#
# Epoch 00073: val_loss did not improve from 0.00078
# Epoch 74/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.4919e-04 - val_loss: 8.2081e-04
#
# Epoch 00074: val_loss did not improve from 0.00078
# Epoch 75/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.4538e-04 - val_loss: 8.0328e-04
#
# Epoch 00075: val_loss did not improve from 0.00078
# Epoch 76/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.4169e-04 - val_loss: 8.1700e-04
#
# Epoch 00076: val_loss did not improve from 0.00078
# Epoch 77/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.4186e-04 - val_loss: 8.1681e-04
#
# Epoch 00077: val_loss did not improve from 0.00078
# Epoch 78/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.4525e-04 - val_loss: 8.3296e-04
#
# Epoch 00078: val_loss did not improve from 0.00078
# Epoch 79/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.3866e-04 - val_loss: 8.2316e-04
#
# Epoch 00079: val_loss did not improve from 0.00078
# Epoch 80/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.3959e-04 - val_loss: 8.1871e-04
#
# Epoch 00080: val_loss did not improve from 0.00078
# Epoch 81/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.3465e-04 - val_loss: 8.2675e-04
#
# Epoch 00081: val_loss did not improve from 0.00078
# Epoch 82/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.3465e-04 - val_loss: 8.0430e-04
#
# Epoch 00082: val_loss did not improve from 0.00078
# Epoch 83/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.3475e-04 - val_loss: 8.0516e-04
#
# Epoch 00083: val_loss did not improve from 0.00078
# Epoch 84/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.3813e-04 - val_loss: 7.9913e-04
#
# Epoch 00084: val_loss did not improve from 0.00078
# Epoch 85/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.2943e-04 - val_loss: 8.1975e-04
#
# Epoch 00085: val_loss did not improve from 0.00078
# Epoch 86/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.3135e-04 - val_loss: 8.2790e-04
#
# Epoch 00086: val_loss did not improve from 0.00078
# Epoch 87/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.3129e-04 - val_loss: 8.0675e-04
#
# Epoch 00087: val_loss did not improve from 0.00078
# Epoch 88/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.3343e-04 - val_loss: 8.1583e-04
#
# Epoch 00088: val_loss did not improve from 0.00078
# Epoch 89/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.2844e-04 - val_loss: 7.9879e-04
#
# Epoch 00089: val_loss did not improve from 0.00078
# Epoch 90/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.2723e-04 - val_loss: 8.1019e-04
#
# Epoch 00090: val_loss did not improve from 0.00078
# Epoch 91/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.2763e-04 - val_loss: 8.2732e-04
#
# Epoch 00091: val_loss did not improve from 0.00078
# Epoch 92/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.2695e-04 - val_loss: 7.8440e-04
#
# Epoch 00092: val_loss did not improve from 0.00078
# Epoch 93/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.2541e-04 - val_loss: 8.5404e-04
#
# Epoch 00093: val_loss did not improve from 0.00078
# Epoch 94/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.2884e-04 - val_loss: 7.9692e-04
#
# Epoch 00094: val_loss did not improve from 0.00078
# Epoch 95/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.2462e-04 - val_loss: 8.0506e-04
#
# Epoch 00095: val_loss did not improve from 0.00078
# Epoch 96/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.2846e-04 - val_loss: 8.4550e-04
#
# Epoch 00096: val_loss did not improve from 0.00078
# Epoch 97/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.2070e-04 - val_loss: 7.9641e-04
#
# Epoch 00097: val_loss did not improve from 0.00078
# Epoch 98/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.2139e-04 - val_loss: 8.2694e-04
#
# Epoch 00098: val_loss did not improve from 0.00078
# Epoch 99/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.2140e-04 - val_loss: 7.8898e-04
#
# Epoch 00099: val_loss did not improve from 0.00078
# Epoch 100/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.1810e-04 - val_loss: 8.0240e-04
#
# Epoch 00100: val_loss did not improve from 0.00078
# Epoch 101/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.1823e-04 - val_loss: 8.1562e-04
#
# Epoch 00101: val_loss did not improve from 0.00078
# Epoch 102/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.1864e-04 - val_loss: 7.7966e-04
#
# Epoch 00102: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 103/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.1654e-04 - val_loss: 7.9355e-04
#
# Epoch 00103: val_loss did not improve from 0.00078
# Epoch 104/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.1532e-04 - val_loss: 7.8356e-04
#
# Epoch 00104: val_loss did not improve from 0.00078
# Epoch 105/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.1743e-04 - val_loss: 8.0389e-04
#
# Epoch 00105: val_loss did not improve from 0.00078
# Epoch 106/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.1761e-04 - val_loss: 8.0182e-04
#
# Epoch 00106: val_loss did not improve from 0.00078
# Epoch 107/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.1486e-04 - val_loss: 8.0483e-04
#
# Epoch 00107: val_loss did not improve from 0.00078
# Epoch 108/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.1124e-04 - val_loss: 8.1084e-04
#
# Epoch 00108: val_loss did not improve from 0.00078
# Epoch 109/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 1.1290e-04 - val_loss: 8.1218e-04
#
# Epoch 00109: val_loss did not improve from 0.00078
# Epoch 110/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.1256e-04 - val_loss: 8.5583e-04
#
# Epoch 00110: val_loss did not improve from 0.00078
# Epoch 111/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0936e-04 - val_loss: 8.0020e-04
#
# Epoch 00111: val_loss did not improve from 0.00078
# Epoch 112/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.0868e-04 - val_loss: 8.4736e-04
#
# Epoch 00112: val_loss did not improve from 0.00078
# Epoch 113/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.0912e-04 - val_loss: 8.1482e-04
#
# Epoch 00113: val_loss did not improve from 0.00078
# Epoch 114/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 1.0471e-04 - val_loss: 8.1747e-04
#
# Epoch 00114: val_loss did not improve from 0.00078
# Epoch 115/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.1154e-04 - val_loss: 7.9547e-04
#
# Epoch 00115: val_loss did not improve from 0.00078
# Epoch 116/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.0549e-04 - val_loss: 8.2139e-04
#
# Epoch 00116: val_loss did not improve from 0.00078
# Epoch 117/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.0601e-04 - val_loss: 7.8991e-04
#
# Epoch 00117: val_loss did not improve from 0.00078
# Epoch 118/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 1.0304e-04 - val_loss: 8.0116e-04
#
# Epoch 00118: val_loss did not improve from 0.00078
# Epoch 119/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.0377e-04 - val_loss: 8.1202e-04
#
# Epoch 00119: val_loss did not improve from 0.00078
# Epoch 120/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 1.0140e-04 - val_loss: 7.9068e-04
#
# Epoch 00120: val_loss did not improve from 0.00078
# Epoch 121/150
# 1712/1712 [==============================] - 0s 273us/step - loss: 1.0122e-04 - val_loss: 8.1698e-04
#
# Epoch 00121: val_loss did not improve from 0.00078
# Epoch 122/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0336e-04 - val_loss: 8.2748e-04
#
# Epoch 00122: val_loss did not improve from 0.00078
# Epoch 123/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0143e-04 - val_loss: 8.2082e-04
#
# Epoch 00123: val_loss did not improve from 0.00078
# Epoch 124/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 1.0427e-04 - val_loss: 7.9741e-04
#
# Epoch 00124: val_loss did not improve from 0.00078
# Epoch 125/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0250e-04 - val_loss: 8.0641e-04
#
# Epoch 00125: val_loss did not improve from 0.00078
# Epoch 126/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0249e-04 - val_loss: 8.2675e-04
#
# Epoch 00126: val_loss did not improve from 0.00078
# Epoch 127/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0028e-04 - val_loss: 8.1170e-04
#
# Epoch 00127: val_loss did not improve from 0.00078
# Epoch 128/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 9.9829e-05 - val_loss: 8.0640e-04
#
# Epoch 00128: val_loss did not improve from 0.00078
# Epoch 129/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.6016e-05 - val_loss: 7.9895e-04
#
# Epoch 00129: val_loss did not improve from 0.00078
# Epoch 130/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 9.8390e-05 - val_loss: 7.9301e-04
#
# Epoch 00130: val_loss did not improve from 0.00078
# Epoch 131/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 9.8793e-05 - val_loss: 8.6475e-04
#
# Epoch 00131: val_loss did not improve from 0.00078
# Epoch 132/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 9.7167e-05 - val_loss: 8.4505e-04
#
# Epoch 00132: val_loss did not improve from 0.00078
# Epoch 133/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 1.0324e-04 - val_loss: 8.0764e-04
#
# Epoch 00133: val_loss did not improve from 0.00078
# Epoch 134/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.9401e-05 - val_loss: 8.2176e-04
#
# Epoch 00134: val_loss did not improve from 0.00078
# Epoch 135/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 9.4595e-05 - val_loss: 8.2786e-04
#
# Epoch 00135: val_loss did not improve from 0.00078
# Epoch 136/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.3048e-05 - val_loss: 8.3303e-04
#
# Epoch 00136: val_loss did not improve from 0.00078
# Epoch 137/150
# 1712/1712 [==============================] - 0s 269us/step - loss: 9.4224e-05 - val_loss: 8.2584e-04
#
# Epoch 00137: val_loss did not improve from 0.00078
# Epoch 138/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.1715e-05 - val_loss: 8.1768e-04
#
# Epoch 00138: val_loss did not improve from 0.00078
# Epoch 139/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.2581e-05 - val_loss: 8.1657e-04
#
# Epoch 00139: val_loss did not improve from 0.00078
# Epoch 140/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 9.2743e-05 - val_loss: 8.0238e-04
#
# Epoch 00140: val_loss did not improve from 0.00078
# Epoch 141/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 8.9100e-05 - val_loss: 8.3826e-04
#
# Epoch 00141: val_loss did not improve from 0.00078
# Epoch 142/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 9.1853e-05 - val_loss: 8.2501e-04
#
# Epoch 00142: val_loss did not improve from 0.00078
# Epoch 143/150
# 1712/1712 [==============================] - 0s 267us/step - loss: 9.2024e-05 - val_loss: 7.9983e-04
#
# Epoch 00143: val_loss did not improve from 0.00078
# Epoch 144/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.0470e-05 - val_loss: 8.4173e-04
#
# Epoch 00144: val_loss did not improve from 0.00078
# Epoch 145/150
# 1712/1712 [==============================] - 0s 272us/step - loss: 8.7165e-05 - val_loss: 8.1807e-04
#
# Epoch 00145: val_loss did not improve from 0.00078
# Epoch 146/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 8.8655e-05 - val_loss: 8.0763e-04
#
# Epoch 00146: val_loss did not improve from 0.00078
# Epoch 147/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 9.0051e-05 - val_loss: 8.2768e-04
#
# Epoch 00147: val_loss did not improve from 0.00078
# Epoch 148/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 8.7422e-05 - val_loss: 7.9028e-04
#
# Epoch 00148: val_loss did not improve from 0.00078
# Epoch 149/150
# 1712/1712 [==============================] - 0s 271us/step - loss: 8.5219e-05 - val_loss: 8.0444e-04
#
# Epoch 00149: val_loss did not improve from 0.00078
# Epoch 150/150
# 1712/1712 [==============================] - 0s 270us/step - loss: 8.6706e-05 - val_loss: 8.2089e-04
#
# Epoch 00150: val_loss did not improve from 0.00078

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'D:\\data\\test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# C:\Users\IVAN\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\IVAN\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., shuffle=True, steps_per_epoch=66, validation_data=(array([[[..., callbacks=[<keras.ca..., epochs=20)`
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/20
# 66/66 [==============================] - 2s 36ms/step - loss: 0.0042 - val_loss: 0.0012
#
# Epoch 00001: val_loss did not improve from 0.00078
# Epoch 2/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00078
# Epoch 3/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00078
# Epoch 4/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00078
# Epoch 5/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00078
# Epoch 6/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00078
# Epoch 7/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00078
# Epoch 8/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00078
# Epoch 9/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00078
# Epoch 10/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00078
# Epoch 11/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00078
# Epoch 12/20
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00078
# Epoch 13/20
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00078
# Epoch 14/20
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00078
# Epoch 15/20
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00078
# Epoch 16/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00078
# Epoch 17/20
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00078
# Epoch 18/20
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00078
# Epoch 19/20
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00078
# Epoch 20/20
# 66/66 [==============================] - 2s 26ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00078

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
